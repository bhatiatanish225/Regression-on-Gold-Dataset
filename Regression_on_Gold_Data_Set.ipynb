# %% [markdown]
# <a href="https://colab.research.google.com/github/bhatiatanish225/Regression-on-Gold-Dataset/blob/main/Regression_on_Gold_Data_Set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from pycaret.utils import version
version()
# Out:
# '3.0.2'

# %%
from pycaret import datasets
from pycaret.datasets import get_data
datasets=get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %%
gold_dataset=get_data("gold") #SN=51
# Out:
#    3M Libor_T-1  EM Bond_T-1  US Bond ETF_T-1  Wheat 1_T-1  Wheat 2_T-1  \
# 0      0.000000     0.000879         0.001050     0.013158     0.013562
# 1     -0.004587     0.004096         0.002383     0.043599     0.041035
# 2     -0.003465    -0.002040         0.000856     0.020444     0.017995
# 3     -0.004624     0.000584        -0.002090    -0.015679    -0.012626
# 4     -0.009292    -0.000486         0.001047    -0.003540    -0.002558
#
#    Crude Palm Oil_T-1  Brent 1_T-1  Brent 2_T-1  Light Crude_T-1  \
# 0            0.003163    -0.007879    -0.004945        -0.003486
# 1            0.040991     0.042356     0.039759         0.029667
# 2            0.003462     0.006222     0.006541         0.007172
# 3            0.021992     0.003029     0.004249         0.002498
# 4           -0.012658    -0.024912    -0.022026        -0.023551
#
#    White Sugar_T-1  ...  MSCI EM_T-22  Shanghai Index_T-22  Nikkei Ind_T-22  \
# ...

# %%
from pycaret.regression import*
s=setup(data=gold_dataset,target='Gold_T+22')
# Out:
# <style type="text/css">
# #T_146cd_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_146cd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_146cd_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_146cd_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_146cd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_146cd_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_146cd_row0_col1" class="data row0 col1" >4537</td>
#     </tr>
#     <tr>
#       <th id="T_146cd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_146cd_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_146cd_row1_col1" class="data row1 col1" >Gold_T+22</td>
#     </tr>
#     <tr>
#       <th id="T_146cd_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
cm=compare_models()
# Out:
# <style type="text/css">
# #T_29d1a th {
#   text-align: left;
# }
# ...

# %%
setup(data=gold_dataset,target='Gold_T+22',normalize=True,normalize_method='zscore')
cm=compare_models()
# Out:
# <style type="text/css">
# #T_659b6_row8_col1, #T_659b6_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_659b6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_659b6_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_659b6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_659b6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_659b6_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_659b6_row0_col1" class="data row0 col1" >1249</td>
#     </tr>
#     <tr>
#       <th id="T_659b6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_659b6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_659b6_row1_col1" class="data row1 col1" >Gold_T+22</td>
#     </tr>
#     <tr>
# ...

# %%
setup(data = gold_dataset, target = 'Gold_T+22',
      feature_selection = True, feature_selection_method = 'classic')
cm = compare_models()
# Out:
# <style type="text/css">
# #T_ccd18_row8_col1, #T_ccd18_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ccd18" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ccd18_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ccd18_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ccd18_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ccd18_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ccd18_row0_col1" class="data row0 col1" >7240</td>
#     </tr>
#     <tr>
#       <th id="T_ccd18_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ccd18_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ccd18_row1_col1" class="data row1 col1" >Gold_T+22</td>
#     </tr>
#     <tr>
# ...

# %%
setup(data = gold_dataset, target = 'Gold_T+22',
      remove_outliers = True, outliers_threshold = 0.05,
      normalize = True, normalize_method = 'zscore',
      transformation = True, transformation_method = 'yeo-johnson')
cm = compare_models()
# Out:
# <style type="text/css">
# #T_32e9c_row8_col1, #T_32e9c_row12_col1, #T_32e9c_row14_col1, #T_32e9c_row16_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_32e9c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_32e9c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_32e9c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_32e9c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_32e9c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_32e9c_row0_col1" class="data row0 col1" >8947</td>
#     </tr>
#     <tr>
#       <th id="T_32e9c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_32e9c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_32e9c_row1_col1" class="data row1 col1" >Gold_T+22</td>
#     </tr>
#     <tr>
# ...

# %%
#Build a Single model.....

# %%
from pycaret.datasets import get_data
from pycaret.regression import*

gold_dataset=get_data("gold")
setup(data =  gold_dataset, target='Gold_T+22')

rfModel = create_model('rf')
# Out:
#    3M Libor_T-1  EM Bond_T-1  US Bond ETF_T-1  Wheat 1_T-1  Wheat 2_T-1  \
# 0      0.000000     0.000879         0.001050     0.013158     0.013562
# 1     -0.004587     0.004096         0.002383     0.043599     0.041035
# 2     -0.003465    -0.002040         0.000856     0.020444     0.017995
# 3     -0.004624     0.000584        -0.002090    -0.015679    -0.012626
# 4     -0.009292    -0.000486         0.001047    -0.003540    -0.002558
#
#    Crude Palm Oil_T-1  Brent 1_T-1  Brent 2_T-1  Light Crude_T-1  \
# 0            0.003163    -0.007879    -0.004945        -0.003486
# 1            0.040991     0.042356     0.039759         0.029667
# 2            0.003462     0.006222     0.006541         0.007172
# 3            0.021992     0.003029     0.004249         0.002498
# 4           -0.012658    -0.024912    -0.022026        -0.023551
#
#    White Sugar_T-1  ...  MSCI EM_T-22  Shanghai Index_T-22  Nikkei Ind_T-22  \
# ...

# %%
newdataset=get_data('gold').iloc[:10]
# Out:
#    3M Libor_T-1  EM Bond_T-1  US Bond ETF_T-1  Wheat 1_T-1  Wheat 2_T-1  \
# 0      0.000000     0.000879         0.001050     0.013158     0.013562
# 1     -0.004587     0.004096         0.002383     0.043599     0.041035
# 2     -0.003465    -0.002040         0.000856     0.020444     0.017995
# 3     -0.004624     0.000584        -0.002090    -0.015679    -0.012626
# 4     -0.009292    -0.000486         0.001047    -0.003540    -0.002558
#
#    Crude Palm Oil_T-1  Brent 1_T-1  Brent 2_T-1  Light Crude_T-1  \
# 0            0.003163    -0.007879    -0.004945        -0.003486
# 1            0.040991     0.042356     0.039759         0.029667
# 2            0.003462     0.006222     0.006541         0.007172
# 3            0.021992     0.003029     0.004249         0.002498
# 4           -0.012658    -0.024912    -0.022026        -0.023551
#
#    White Sugar_T-1  ...  MSCI EM_T-22  Shanghai Index_T-22  Nikkei Ind_T-22  \
# ...

# %%
newPredictions = predict_model(rfModel, data = newdataset)
newPredictions
# Out:
# <style type="text/css">
# </style>
# <table id="T_70ffe" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_70ffe_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_70ffe_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_70ffe_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_70ffe_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_70ffe_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_70ffe_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_70ffe_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70ffe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_70ffe_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_70ffe_row0_col1" class="data row0 col1" >0.0166</td>
# ...

# %%
import matplotlib.pyplot as plt

# %%
predicted=newPredictions.iloc[:,-1]
actual = newPredictions.iloc[:,-2]
plt.scatter(actual, predicted)

# %%
from google.colab import files
files.download('/content/download.png')
from google.colab import files

newPredictions.to_csv("NewPredictions.csv", index=False)
files.download('NewPredictions.csv')
sm = save_model(rfModel, 'rfModelFile')

from google.colab import files
files.download('rfModelFile.pkl')
# Out:
# Transformation Pipeline and Model Successfully Saved

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-368844d7-95c4-4e47-974d-9461029d06ce" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-368844d7-95c4-4e47-974d-9461029d06ce">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
rfModel = create_model('rf', verbose=False)
plot_model(rfModel, plot='feature')
